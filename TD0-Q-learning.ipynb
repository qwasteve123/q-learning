# %%
import numpy as np
import gymnasium as gym
import random

# %%
class QLearn:
    def __init__(self,env:gym.Env):
        self.env = env
        self.obs_space: gym.spaces.Box = env.observation_space 

    def set_num_of_increments(self,num_of_increments: np.ndarray):
        self.num_of_increments: np.ndarray = num_of_increments
        self.increment: np.ndarray = self._obs_increment()

    
    def _obs_increment(self) -> np.ndarray:
        high = np.array([1.5,1.5,3,3,1.5,3,1,1])
        low = np.array([-1.5,-1.5,-3,-3,-1.5,-3,0,0])
        # range = self.obs_space.high - self.obs_space.low
        range = high - low
        increment = range / self.num_of_increments
        return increment

    def regulate_obs(self, obs: np.ndarray,time_step:int = None)-> np.ndarray:
        float_num = obs // self.increment + (self.num_of_increments //2)
        float_num = float_num[:-2]
        bool_num = obs[-2:]

        low_limit = np.zeros(8)
        high_limit = self.num_of_increments -1

        reg_obs = np.concatenate((float_num,bool_num)).astype(int)
        reg_obs = reg_obs.clip(low_limit,high_limit).astype(int)
        if time_step:
            return self.add_time_dim(reg_obs,time_step)
        else:
            return reg_obs
    
    def add_time_dim(self,obs:np.ndarray, time_step: int):
        time_incr = 20
        time_step = min(4,time_step//time_incr)
        return np.insert(obs,0,time_step)


def create_Q_table(*dim):
    return np.zeros(dim)

#Bellman equation, Q
def Q_observed(s2_reward:np.float64, s2_obs: np.ndarray, q_table: np.ndarray, gamma:float):
    arg_max_Q = np.argmax(q_table[tuple(s2_obs)])
    return s2_reward + gamma * arg_max_Q

def Q_observed(reward:np.float64, s2_obs: np.ndarray, q_table: np.ndarray, gamma:float):
    arg_max_Q = np.argmax(q_table[tuple(s2_obs)])
    return reward + gamma * arg_max_Q

def Q_expected(s1_obs: np.ndarray,s1_action: np.int64, q_table: np.ndarray):
    index = *s1_obs , s1_action
    return q_table[index]

def update_Q(Q_observed: float,Q_expected: float, alpha: float, q_table: np.ndarray,s1_obs: np.ndarray,s1_action: np.int64):
    index = *s1_obs , s1_action
    q_table[index] = Q_expected + alpha * (Q_observed - Q_expected)
    return q_table

def action_policy(q_table: np.ndarray, s1_obs: np.ndarray):
    return np.argmax(q_table[tuple(s1_obs)])


def expo_decay(large_epsilon, small_epsilon, epoch, steps):
    a = large_epsilon
    b = small_epsilon
    e = np.e
    z = 1- steps/epoch
    return z*((a-b)/e)*(e**z)+b

# %%
time_incre = 5
states = np.array([10,10,10,10,10,10,2,2])
# q_table = create_Q_table(time_incre,*states,4)
q_table = create_Q_table(*states,4)

# %%
env = gym.make("LunarLander-v2")
agent = QLearn(env)

sample = env.observation_space.sample()
print(sample)
agent.set_num_of_increments(states)
print(agent.regulate_obs(sample,70))
# Out:
# [ 0.8863708   0.18356812  4.439961    4.8638315  -1.8767257  -0.27511042
#   0.38076794  0.08213469]
# [3 7 5 9 9 0 4 0 0]

# %%
env = gym.make("LunarLander-v2")
observation, info = env.reset()
max_alpha = 0.1
min_alpha = 0.001
gamma = 0.55
# epsilon = 0.1
max_epsilon = 0.3
min_epsilon = 0.001
# num_of_increments = 10
epoch = 4_000_000

agent = QLearn(env)
agent.set_num_of_increments(states)
game_step = 0
obs = agent.regulate_obs(observation)

# %%
for _ in range(epoch):
    epsilon = expo_decay(max_epsilon,min_epsilon,epoch,_)
    alpha = expo_decay(max_alpha,min_alpha,epoch,_)
    policy_action = action_policy(q_table,obs)
    action = policy_action if random.random() > epsilon else env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    new_obs = agent.regulate_obs(observation)

    q_observe = Q_observed(reward,new_obs,q_table,gamma)
    q_expected = Q_expected(obs,action,q_table)

    update_Q(q_observe,q_expected,alpha,q_table,obs,action)

    if terminated or truncated:
        observation, info = env.reset()
        obs = agent.regulate_obs(observation)
    else:
        obs = new_obs

    if _ % 100_000 == 0:
        print(_)
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000

# %%
from playsound import playsound
playsound('./yakemashita.wav')

# %%
env = gym.make("LunarLander-v2",render_mode="human")
observation, info = env.reset()
obs = agent.regulate_obs(observation)



for _ in range(epoch):
    game_step += 1
    action = action_policy(q_table,obs)
    observation, reward, terminated, truncated, info = env.step(action)
    new_obs = agent.regulate_obs(observation)

    if terminated or truncated:
        observation, info = env.reset()
        game_step = 0
        obs = agent.regulate_obs(observation)
    else:
        obs = new_obs
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 10
#       8 game_step += 1
#       9 action = action_policy(q_table,obs)
# ---> 10 observation, reward, terminated, truncated, info = env.step(action)
#      11 new_obs = agent.regulate_obs(observation)
#      13 if terminated or truncated:
#
# File c:\Users\waito\Desktop\Python_projects\Reinforcement\reinforce_env\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\waito\Desktop\Python_projects\Reinforcement\reinforce_env\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\waito\Desktop\Python_projects\Reinforcement\reinforce_env\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\waito\Desktop\Python_projects\Reinforcement\reinforce_env\lib\site-packages\gymnasium\envs\box2d\lunar_lander.py:675, in LunarLander.step(self, action)
#     672     reward = +100
#     674 if self.render_mode == "human":
# --> 675     self.render()
#     676 return np.array(state, dtype=np.float32), reward, terminated, False, {}
#
# File c:\Users\waito\Desktop\Python_projects\Reinforcement\reinforce_env\lib\site-packages\gymnasium\envs\box2d\lunar_lander.py:787, in LunarLander.render(self)
#     785     self.screen.blit(self.surf, (0, 0))
#     786     pygame.event.pump()
# --> 787     self.clock.tick(self.metadata["render_fps"])
#     788     pygame.display.flip()
#     789 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
env = gym.make("LunarLander-v2")
observation, info = env.reset()

obs = agent.regulate_obs(observation,0)


term_count = 0
survival_count = 0
for _ in range(1000000):
    game_step += 1

    policy_action = action_policy(q_table,obs)
    action = policy_action
    observation, reward, terminated, truncated, info = env.step(action)
    new_obs = agent.regulate_obs(observation)

    if terminated or truncated:
        observation, info = env.reset()
        game_step = 0
        obs = agent.regulate_obs(observation)
        term_count += 1
        if reward > 99:
            survival_count +=1
            print(f"term: {term_count}, survival rate: {survival_count/term_count}")
    else:
        obs = new_obs
print(100000/term_count)
# Out:
# term: 1, survival rate: 1.0
# term: 3, survival rate: 0.6666666666666666
# term: 30, survival rate: 0.1
# term: 47, survival rate: 0.0851063829787234
# term: 55, survival rate: 0.09090909090909091
# term: 68, survival rate: 0.08823529411764706
# term: 104, survival rate: 0.0673076923076923
# term: 116, survival rate: 0.06896551724137931
# term: 120, survival rate: 0.075
# term: 132, survival rate: 0.07575757575757576
# term: 151, survival rate: 0.0728476821192053
# term: 154, survival rate: 0.07792207792207792
# term: 169, survival rate: 0.07692307692307693
# term: 189, survival rate: 0.07407407407407407
# term: 203, survival rate: 0.07389162561576355
# term: 207, survival rate: 0.07729468599033816
# term: 211, survival rate: 0.08056872037914692
# term: 226, survival rate: 0.07964601769911504
# term: 234, survival rate: 0.0811965811965812
# term: 249, survival rate: 0.08032128514056225
# term: 293, survival rate: 0.07167235494880546
# term: 309, survival rate: 0.07119741100323625
# term: 325, survival rate: 0.07076923076923076
# term: 330, survival rate: 0.07272727272727272
# term: 335, survival rate: 0.07462686567164178
# term: 339, survival rate: 0.07669616519174041
# term: 344, survival rate: 0.07848837209302326
# term: 345, survival rate: 0.08115942028985507
# term: 377, survival rate: 0.07692307692307693
# term: 392, survival rate: 0.07653061224489796
# term: 396, survival rate: 0.07828282828282829
# term: 433, survival rate: 0.07390300230946882
# term: 437, survival rate: 0.07551487414187644
# term: 453, survival rate: 0.07505518763796909
# term: 468, survival rate: 0.07478632478632478
# term: 475, survival rate: 0.07578947368421053
# term: 481, survival rate: 0.07692307692307693
# term: 487, survival rate: 0.07802874743326489
# term: 490, survival rate: 0.07959183673469387
# term: 505, survival rate: 0.07920792079207921
# term: 508, survival rate: 0.08070866141732283
# term: 514, survival rate: 0.08171206225680934
# term: 528, survival rate: 0.08143939393939394
# term: 532, survival rate: 0.08270676691729323
# term: 547, survival rate: 0.08226691042047532
# term: 562, survival rate: 0.08185053380782918
# term: 564, survival rate: 0.08333333333333333
# term: 565, survival rate: 0.08495575221238938
# term: 578, survival rate: 0.0847750865051903
# term: 579, survival rate: 0.08635578583765112
# term: 582, survival rate: 0.08762886597938144
# term: 585, survival rate: 0.08888888888888889
# term: 589, survival rate: 0.0899830220713073
# term: 597, survival rate: 0.09045226130653267
# term: 607, survival rate: 0.09060955518945635
# term: 617, survival rate: 0.09076175040518639
# term: 622, survival rate: 0.09163987138263666
# term: 625, survival rate: 0.0928
# term: 628, survival rate: 0.09394904458598727
# term: 638, survival rate: 0.09404388714733543
# term: 649, survival rate: 0.09399075500770417
# term: 657, survival rate: 0.0943683409436834
# term: 667, survival rate: 0.0944527736131934
# term: 675, survival rate: 0.09481481481481481
# term: 676, survival rate: 0.09615384615384616
# term: 686, survival rate: 0.09620991253644315
# term: 688, survival rate: 0.09738372093023256
# term: 699, survival rate: 0.09728183118741059
# term: 718, survival rate: 0.09610027855153204
# term: 740, survival rate: 0.0945945945945946
# term: 759, survival rate: 0.09354413702239789
# term: 761, survival rate: 0.09461235216819974
# term: 793, survival rate: 0.09205548549810845
# term: 795, survival rate: 0.0930817610062893
# term: 799, survival rate: 0.09386733416770963
# term: 814, survival rate: 0.09336609336609336
# term: 815, survival rate: 0.09447852760736196
# term: 818, survival rate: 0.09535452322738386
# term: 822, survival rate: 0.09610705596107055
# term: 824, survival rate: 0.0970873786407767
# term: 829, survival rate: 0.097708082026538
# term: 834, survival rate: 0.09832134292565947
# term: 848, survival rate: 0.09787735849056604
# term: 849, survival rate: 0.0989399293286219
# term: 850, survival rate: 0.1
# term: 851, survival rate: 0.10105757931844889
# term: 853, survival rate: 0.10199296600234467
# term: 867, survival rate: 0.10149942329873125
# term: 875, survival rate: 0.10171428571428572
# term: 889, survival rate: 0.10123734533183353
# term: 936, survival rate: 0.09722222222222222
# term: 953, survival rate: 0.09653725078698845
# term: 957, survival rate: 0.09717868338557993
# term: 973, survival rate: 0.09660842754367935
# term: 977, survival rate: 0.09723643807574207
# term: 987, survival rate: 0.0972644376899696
# term: 1008, survival rate: 0.09623015873015874
# term: 1011, survival rate: 0.09693372898120672
# term: 1015, survival rate: 0.09753694581280788
# term: 1018, survival rate: 0.09823182711198428
# term: 1029, survival rate: 0.09815354713313897
# term: 1031, survival rate: 0.09893307468477207
# term: 1032, survival rate: 0.0998062015503876
# term: 1051, survival rate: 0.09895337773549001
# term: 1056, survival rate: 0.09943181818181818
# term: 1071, survival rate: 0.09897292250233426
# term: 1095, survival rate: 0.09771689497716896
# term: 1098, survival rate: 0.09836065573770492
# term: 1100, survival rate: 0.09909090909090909
# term: 1123, survival rate: 0.09795191451469279
# term: 1126, survival rate: 0.09857904085257549
# term: 1130, survival rate: 0.09911504424778761
# term: 1134, survival rate: 0.09964726631393298
# term: 1155, survival rate: 0.0987012987012987
# term: 1166, survival rate: 0.09862778730703259
# term: 1167, survival rate: 0.09940017137960583
# term: 1170, survival rate: 0.1
# term: 1185, survival rate: 0.09957805907172995
# term: 1204, survival rate: 0.09883720930232558
# term: 1212, survival rate: 0.09900990099009901
# term: 1216, survival rate: 0.09950657894736842
# term: 1218, survival rate: 0.10016420361247948
# term: 1232, survival rate: 0.09983766233766234
# term: 1236, survival rate: 0.10032362459546926
# term: 1240, survival rate: 0.10080645161290322
# term: 1244, survival rate: 0.10128617363344052
# term: 1247, survival rate: 0.10184442662389735
# term: 1250, survival rate: 0.1024
# term: 1256, survival rate: 0.10270700636942676
# term: 1291, survival rate: 0.10069713400464755
# term: 1297, survival rate: 0.10100231303006939
# term: 1302, survival rate: 0.10138248847926268
# term: 1320, survival rate: 0.10075757575757575
# term: 1322, survival rate: 0.10136157337367625
# term: 1326, survival rate: 0.10180995475113122
# term: 1332, survival rate: 0.1021021021021021
# term: 1335, survival rate: 0.10262172284644194
# term: 1363, survival rate: 0.1012472487160675
# term: 1411, survival rate: 0.09851169383416017
# term: 1414, survival rate: 0.09900990099009901
# term: 1424, survival rate: 0.09901685393258428
# term: 1433, survival rate: 0.09909281228192603
# term: 1440, survival rate: 0.09930555555555555
# term: 1453, survival rate: 0.09910529938059189
# term: 1455, survival rate: 0.09965635738831616
# term: 1456, survival rate: 0.10027472527472528
# term: 1472, survival rate: 0.09986413043478261
# term: 1485, survival rate: 0.09966329966329966
# term: 1488, survival rate: 0.10013440860215053
# term: 1494, survival rate: 0.10040160642570281
# term: 1496, survival rate: 0.10093582887700535
# term: 1512, survival rate: 0.10052910052910052
# term: 1515, survival rate: 0.100990099009901
# term: 1541, survival rate: 0.099935107073329
# term: 1542, survival rate: 0.10051880674448768
# term: 1545, survival rate: 0.10097087378640776
# term: 1591, survival rate: 0.09868007542426147
# term: 1593, survival rate: 0.09918392969240426
# term: 1607, survival rate: 0.09894212818917238
# term: 1616, survival rate: 0.09900990099009901
# term: 1619, survival rate: 0.09944410129709698
# term: 1642, survival rate: 0.09866017052375152
# term: 1643, survival rate: 0.09920876445526476
# term: 1664, survival rate: 0.0985576923076923
# term: 1687, survival rate: 0.0978067575577949
# term: 1694, survival rate: 0.09799291617473435
# term: 1699, survival rate: 0.09829311359623308
# term: 1701, survival rate: 0.09876543209876543
# term: 1707, survival rate: 0.09900410076157
# term: 1726, survival rate: 0.0984936268829664
# term: 1739, survival rate: 0.09833237492811961
# term: 1756, survival rate: 0.0979498861047836
# term: 1771, survival rate: 0.09768492377188029
# term: 1781, survival rate: 0.09769792251544077
# term: 1806, survival rate: 0.09689922480620156
# term: 1834, survival rate: 0.09596510359869138
# term: 1836, survival rate: 0.09640522875816994
# term: 1844, survival rate: 0.09652928416485901
# term: 1846, survival rate: 0.09696641386782232
# term: 1854, survival rate: 0.0970873786407767
# term: 1864, survival rate: 0.0971030042918455
# term: 1869, survival rate: 0.09737827715355805
# term: 1916, survival rate: 0.09551148225469729
# term: 1920, survival rate: 0.09583333333333334
# term: 1933, survival rate: 0.09570615623383343
# term: 1934, survival rate: 0.09617373319544985
# term: 1943, survival rate: 0.09624292331446217
# term: 2014, survival rate: 0.09334657398212512
# term: 2018, survival rate: 0.09365708622398414
# term: 2021, survival rate: 0.09401286491835725
# term: 2029, survival rate: 0.0941350418925579
# term: 2033, survival rate: 0.09444171175602557
# term: 2039, survival rate: 0.0946542422756253
# term: 2054, survival rate: 0.09444985394352483
# term: 2074, survival rate: 0.0940212150433944
# term: 2094, survival rate: 0.0936007640878701
# term: 2100, survival rate: 0.09380952380952381
# term: 2117, survival rate: 0.09352857817666509
# term: 2125, survival rate: 0.09364705882352942
# term: 2131, survival rate: 0.09385265133740028
# term: 2138, survival rate: 0.0940130963517306
# term: 2140, survival rate: 0.09439252336448598
# term: 2142, survival rate: 0.09477124183006536
# term: 2156, survival rate: 0.09461966604823747
# term: 2188, survival rate: 0.09369287020109689
# term: 2201, survival rate: 0.09359382099045888
# term: 2216, survival rate: 0.09341155234657039
# term: 2217, survival rate: 0.09382047812359044
# term: 2218, survival rate: 0.09422903516681695
# term: 2227, survival rate: 0.09429726088908846
# term: 2247, survival rate: 0.09390298175344905
# term: 2249, survival rate: 0.09426411738550466
# term: 2263, survival rate: 0.09412284577993814
# term: 2269, survival rate: 0.09431467606875275
# term: 2270, survival rate: 0.0947136563876652
# term: 2305, survival rate: 0.09370932754880694
# term: 2308, survival rate: 0.09402079722703639
# term: 2311, survival rate: 0.09433145824318477
# term: 2324, survival rate: 0.0942340791738382
# term: 2328, survival rate: 0.09450171821305842
# term: 2336, survival rate: 0.09460616438356165
# term: 2342, survival rate: 0.09479077711357814
# term: 2344, survival rate: 0.09513651877133106
# term: 2350, survival rate: 0.09531914893617022
# term: 2355, survival rate: 0.09554140127388536
# term: 2370, survival rate: 0.09535864978902954
# term: 2386, survival rate: 0.09513830678960604
# term: 2390, survival rate: 0.09539748953974896
# term: 2394, survival rate: 0.09565580618212197
# term: 2415, survival rate: 0.09523809523809523
# term: 2432, survival rate: 0.09498355263157894
# term: 2443, survival rate: 0.09496520671305772
# term: 2462, survival rate: 0.09463850528025995
# term: 2504, survival rate: 0.09345047923322684
# term: 2506, survival rate: 0.09377494014365523
# term: 2514, survival rate: 0.09387430389817025
# term: 2516, survival rate: 0.09419713831478538
# term: 2525, survival rate: 0.09425742574257426
# term: 2534, survival rate: 0.09431728492501973
# term: 2537, survival rate: 0.09459992116673237
# term: 2544, survival rate: 0.09473270440251573
# term: 2549, survival rate: 0.09493919183993724
# term: 2552, survival rate: 0.09521943573667711
# term: 2558, survival rate: 0.09538702111024237
# term: 2561, survival rate: 0.09566575556423272
# term: 2563, survival rate: 0.09598127194693719
# term: 2570, survival rate: 0.09610894941634242
# term: 2576, survival rate: 0.09627329192546584
# term: 2584, survival rate: 0.09636222910216719
# term: 2592, survival rate: 0.09645061728395062
# term: 2601, survival rate: 0.09650134563629373
# term: 2603, survival rate: 0.0968113714944295
# term: 2619, survival rate: 0.09660175639557082
# term: 2657, survival rate: 0.0955965374482499
# term: 2665, survival rate: 0.09568480300187618
# term: 2672, survival rate: 0.09580838323353294
# term: 2676, survival rate: 0.0960388639760837
# term: 2701, survival rate: 0.09552017771195853
# term: 2707, survival rate: 0.09567787218322867
# term: 2708, survival rate: 0.09601181683899557
# term: 2710, survival rate: 0.096309963099631
# term: 2757, survival rate: 0.09503083061298513
# term: 2784, survival rate: 0.09446839080459771
# term: 2786, survival rate: 0.09475951184493898
# term: 2791, survival rate: 0.0949480472948764
# term: 2823, survival rate: 0.09422600070846616
# term: 2840, survival rate: 0.09401408450704225
# term: 2849, survival rate: 0.09406809406809406
# term: 2859, survival rate: 0.09408884225253585
# term: 2860, survival rate: 0.0944055944055944
# term: 2863, survival rate: 0.09465595529165212
# term: 2869, survival rate: 0.0948065528058557
# term: 2873, survival rate: 0.09502262443438914
# term: 2876, survival rate: 0.0952712100139082
# term: 2899, survival rate: 0.09486029665401863
# term: 2946, survival rate: 0.09368635437881874
# 33.863867253640365

# %%
env.close
# Out:
# <bound method Wrapper.close of <TimeLimit<OrderEnforcing<PassiveEnvChecker<LunarLander<LunarLander-v2>>>>>>

# %%
# Out:
# array([20, 20, 20, 20, 20, 20,  2,  2])
